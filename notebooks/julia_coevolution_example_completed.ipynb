# %% [markdown]
# # <img src="https://github.com/JuliaLang/julia-logo-graphics/raw/master/images/julia-logo-color.png" height="40" /> _ALIFE Phylogeny Tutorial Notebook_
#
# [Link to original julia notebook template](https://github.com/ageron/julia_notebooks/blob/main/Julia_Colab_Notebook_Template.ipynb)
#
# This notebook contains a simple evolving system with synchronous generations, which is typical for most evolutionary computing systems. That is, each generation, a population of candidate solutions are evaluated and selected to reproduce. This process repeats for a desired number of generations.
#
# In this example, we implement phylogeny tracking for a continuous, 1-dimensional version of [the numbers game](http://www.demo.cs.brandeis.edu/pr/number_games/).
#
# Throughout the code, we have left comments where phylogeny tracking code should be added. If you're working on this during the tutorial at ALife 2024, feel free to ask for our help! We're happy to walk you through anything!

# %% [markdown]
# # Install Julia
# 1. Work on a copy of this notebook: _File_ > _Save a copy in Drive_ (you will need a Google account). Alternatively, you can download the notebook using _File_ > _Download .ipynb_, then upload it to [Colab](https://colab.research.google.com/).
# 2. Execute the following cell (click on it and press Ctrl+Enter) to install Julia, IJulia and other packages (if needed, update `JULIA_VERSION` and the other parameters). This takes a couple of minutes.
# 3. Reload this page (press Ctrl+R, or ⌘+R, or the F5 key) and continue to the next section.
#
# _Notes_:
# * If your Colab Runtime gets reset (e.g., due to inactivity), repeat steps 2, 3 and 4.
# * After installation, if you want to change the Julia version or activate/deactivate the GPU, you will need to reset the Runtime: _Runtime_ > _Factory reset runtime_ and repeat steps 3 and 4.

# %%
%%shell
set -e

#---------------------------------------------------#
JULIA_VERSION="1.10.4" # any version ≥ 0.7.0
JULIA_PACKAGES="IJulia"
JULIA_PACKAGES_IF_GPU="CUDA" # or CuArrays for older Julia versions
JULIA_NUM_THREADS=8
#---------------------------------------------------#

if [ -z `which julia` ]; then
  # Install Julia
  JULIA_VER=`cut -d '.' -f -2 <<< "$JULIA_VERSION"`
  echo "Installing Julia $JULIA_VERSION on the current Colab Runtime..."
  BASE_URL="https://julialang-s3.julialang.org/bin/linux/x64"
  URL="$BASE_URL/$JULIA_VER/julia-$JULIA_VERSION-linux-x86_64.tar.gz"
  wget -nv $URL -O /tmp/julia.tar.gz # -nv means "not verbose"
  tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
  rm /tmp/julia.tar.gz

  # Install Packages
  nvidia-smi -L &> /dev/null && export GPU=1 || export GPU=0
  if [ $GPU -eq 1 ]; then
    JULIA_PACKAGES="$JULIA_PACKAGES $JULIA_PACKAGES_IF_GPU"
  fi
  for PKG in `echo $JULIA_PACKAGES`; do
    echo "Installing Julia package $PKG..."
    julia -e 'using Pkg; pkg"add '$PKG'; precompile;"' &> /dev/null
  done

  # Install kernel and rename it to "julia"
  echo "Installing IJulia kernel..."
  julia -e 'using IJulia; IJulia.installkernel("julia", env=Dict(
      "JULIA_NUM_THREADS"=>"'"$JULIA_NUM_THREADS"'"))'
  KERNEL_DIR=`julia -e "using IJulia; print(IJulia.kerneldir())"`
  KERNEL_NAME=`ls -d "$KERNEL_DIR"/julia*`
  mv -f $KERNEL_NAME "$KERNEL_DIR"/julia

  echo ''
  echo "Successfully installed `julia -v`!"
  echo "Please reload this page (press Ctrl+R, ⌘+R, or the F5 key) then"
  echo "jump to the 'Checking the Installation' section."
fi
# Out:
# Installing Julia 1.10.4 on the current Colab Runtime...
# 2024-07-24 08:32:49 URL:https://julialang-s3.julialang.org/bin/linux/x64/1.10/julia-1.10.4-linux-x86_64.tar.gz [173704015/173704015] -> "/tmp/julia.tar.gz" [1]
# Installing Julia package IJulia...
# Installing IJulia kernel...
# [ Info: Installing julia kernelspec in /root/.local/share/jupyter/kernels/julia-1.10
#
# Successfully installed julia version 1.10.4!
# Please reload this page (press Ctrl+R, ⌘+R, or the F5 key) then
# jump to the 'Checking the Installation' section.

# %% [markdown]
# ## Checking the Installation
# The `versioninfo()` function should print your Julia version and some other info about the system. If you get an error, refresh/reload this page.

# %%
versioninfo()
# Out:
# Julia Version 1.10.4
# Commit 48d4fd48430 (2024-06-04 10:41 UTC)
# Build Info:
#   Official https://julialang.org/ release
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#   CPU: 2 × Intel(R) Xeon(R) CPU @ 2.20GHz
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-15.0.7 (ORCJIT, broadwell)
# Threads: 8 default, 0 interactive, 2 GC (on 2 virtual cores)
# Environment:
#   LD_LIBRARY_PATH = /usr/local/nvidia/lib:/usr/local/nvidia/lib64
#   JULIA_NUM_THREADS = 8

# %% [markdown]
# If the above cell gives you an error, refresh this page.
#
# # Install Jevo.jl and Dependencies
#
# Run the following cell to install the `phylo-tutorial` branch of [Jevo.jl](https://www.github.com/jarbus/Jevo.jl) and its dependencies. This branch has all of the neuro-evolution code stripped out to install faster.
#
# [Jevo.jl](https://www.github.com/jarbus/Jevo.jl) is currently in alpha, development docs can be found [here](https://jarbus.github.io/Jevo.jl/dev). Jevo is only required for the final section of this notebook.
#
# This cell should take ~10 minutes on Google Collab. In the meantime, you can move on to the coding challenges below!

# %%
]add StatsBase https://github.com/jarbus/XPlot.jl.git https://github.com/jarbus/PhylogeneticTrees.jl.git https://github.com/jarbus/Jevo.jl.git#phylo-tutorial StableRNGs Logging
# Out:
#      Cloning git-repo `https://github.com/jarbus/XPlot.jl.git`
#     Updating git-repo `https://github.com/jarbus/XPlot.jl.git`
#      Cloning git-repo `https://github.com/jarbus/PhylogeneticTrees.jl.git`
#     Updating git-repo `https://github.com/jarbus/PhylogeneticTrees.jl.git`
#      Cloning git-repo `https://github.com/jarbus/Jevo.jl.git`
#     Updating git-repo `https://github.com/jarbus/Jevo.jl.git`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed Calculus ───────────────────── v0.5.1
#    Installed libfdk_aac_jll ─────────────── v2.0.2+0
#    Installed LRUCache ───────────────────── v1.6.1
#    Installed GR_jll ─────────────────────── v0.73.7+0
#    Installed JpegTurbo_jll ──────────────── v3.0.3+0
#    Installed x265_jll ───────────────────── v3.5.0+0
#    Installed HypergeometricFunctions ────── v0.3.23
#    Installed StatsFuns ──────────────────── v1.3.1
#    Installed LoggingExtras ──────────────── v1.0.3
#    Installed Accessors ──────────────────── v0.1.37
#    Installed Libmount_jll ───────────────── v2.40.1+0
#    Installed Unitful ────────────────────── v1.21.0
#    Installed LERC_jll ───────────────────── v3.0.0+1
#    Installed Opus_jll ───────────────────── v1.3.2+0
#    Installed Bootstrap ──────────────────── v2.4.0
#    Installed InlineStrings ──────────────── v1.4.2
#    Installed Xorg_xkbcomp_jll ───────────── v1.4.6+0
#    Installed Measures ───────────────────── v0.3.2
#    Installed PDMats ─────────────────────── v0.11.31
#    Installed RelocatableFolders ─────────── v1.0.1
#    Installed Contour ────────────────────── v0.6.3
#    Installed ConcurrentUtilities ────────── v2.4.2
#    Installed Grisu ──────────────────────── v1.0.2
#    Installed Xorg_xcb_util_image_jll ────── v0.4.0+1
#    Installed Xorg_xcb_util_wm_jll ───────── v0.4.1+1
#    Installed RecipesPipeline ────────────── v0.6.12
#    Installed Roots ──────────────────────── v2.1.6
#    Installed PlotUtils ──────────────────── v1.4.1
#    Installed OpenSSL ────────────────────── v1.4.3
#    Installed InvertedIndices ────────────── v1.3.0
#    Installed Xorg_libpthread_stubs_jll ──── v0.1.1+0
#    Installed ColorSchemes ───────────────── v3.26.0
#    Installed DelimitedFiles ─────────────── v1.9.1
#    Installed HTTP ───────────────────────── v1.10.8
#    Installed DataFrames ─────────────────── v1.6.1
#    Installed Xorg_libSM_jll ─────────────── v1.2.4+0
#    Installed GR ─────────────────────────── v0.73.7
#    Installed Cairo_jll ──────────────────── v1.18.0+2
#    Installed Xorg_xcb_util_jll ──────────── v0.4.0+1
#    Installed Fontconfig_jll ─────────────── v2.13.96+0
#    Installed Libgpg_error_jll ───────────── v1.49.0+0
#    Installed Xorg_libxkbfile_jll ────────── v1.1.2+0
#    Installed IrrationalConstants ────────── v0.2.2
#    Installed Xorg_libXinerama_jll ───────── v1.1.4+4
#    Installed Xorg_libXau_jll ────────────── v1.0.11+0
#    Installed Showoff ────────────────────── v1.0.3
#    Installed EpollShim_jll ──────────────── v0.0.20230411+0
#    Installed SpecialFunctions ───────────── v2.4.0
#    Installed PtrArrays ──────────────────── v1.2.0
#    Installed FFMPEG ─────────────────────── v0.4.1
#    Installed Missings ───────────────────── v1.2.0
#    Installed Hwloc_jll ──────────────────── v2.11.1+0
#    Installed SimpleBufferStream ─────────── v1.1.0
#    Installed xkbcommon_jll ──────────────── v1.4.1+1
#    Installed Bzip2_jll ──────────────────── v1.0.8+1
#    Installed Pipe ───────────────────────── v1.3.0
#    Installed Xorg_xcb_util_keysyms_jll ──── v0.4.0+1
#    Installed SentinelArrays ─────────────── v1.4.5
#    Installed XZ_jll ─────────────────────── v5.4.6+0
#    Installed HarfBuzz_jll ───────────────── v2.8.1+1
#    Installed NaNMath ────────────────────── v1.0.2
#    Installed PlotThemes ─────────────────── v3.2.0
#    Installed TranscodingStreams ─────────── v0.11.1
#    Installed MicrosoftMPI_jll ───────────── v10.1.4+2
#    Installed fzf_jll ────────────────────── v0.43.0+0
#    Installed LZO_jll ────────────────────── v2.10.2+0
#    Installed FriBidi_jll ────────────────── v1.0.14+0
#    Installed HypothesisTests ────────────── v0.11.0
#    Installed UnicodeFun ─────────────────── v0.4.1
#    Installed MPIPreferences ─────────────── v0.1.11
#    Installed Rmath_jll ──────────────────── v0.4.2+0
#    Installed DataStructures ─────────────── v0.18.20
#    Installed StatsModels ────────────────── v0.7.3
#    Installed GLFW_jll ───────────────────── v3.4.0+0
#    Installed Compat ─────────────────────── v4.15.0
#    Installed Colors ─────────────────────── v0.12.11
#    Installed FreeType2_jll ──────────────── v2.13.2+0
#    Installed JLFzf ──────────────────────── v0.1.7
#    Installed CodecZlib ──────────────────── v0.7.5
#    Installed StatsAPI ───────────────────── v1.7.0
#    Installed x264_jll ───────────────────── v2021.5.5+0
#    Installed ExceptionUnwrapping ────────── v0.1.10
#    Installed HDF5_jll ───────────────────── v1.14.3+3
#    Installed Scratch ────────────────────── v1.2.1
#    Installed Xorg_libxcb_jll ────────────── v1.17.0+0
#    Installed StatsBase ──────────────────── v0.34.3
#    Installed libpng_jll ─────────────────── v1.6.43+1
#    Installed mtdev_jll ──────────────────── v1.1.6+0
#    Installed MPICH_jll ──────────────────── v4.2.2+0
#    Installed libaom_jll ─────────────────── v3.9.0+0
#    Installed PrettyTables ───────────────── v2.3.2
#    Installed ColorTypes ─────────────────── v0.11.5
#    Installed gperf_jll ──────────────────── v3.1.1+0
#    Installed Xorg_libXext_jll ───────────── v1.3.6+0
#    Installed Zstd_jll ───────────────────── v1.5.6+0
#    Installed eudev_jll ──────────────────── v3.2.9+0
#    Installed TensorCore ─────────────────── v0.1.1
#    Installed Plots ──────────────────────── v1.40.5
#    Installed Expat_jll ──────────────────── v2.6.2+0
#    Installed PooledArrays ───────────────── v1.4.3
#    Installed Format ─────────────────────── v1.3.7
#    Installed TableTraits ────────────────── v1.0.1
#    Installed Xorg_xcb_util_cursor_jll ───── v0.1.4+0
#    Installed OpenMPI_jll ────────────────── v4.1.6+0
#    Installed Libtiff_jll ────────────────── v4.5.1+1
#    Installed ConstructionBase ───────────── v1.5.6
#    Installed ColorVectorSpace ───────────── v0.10.0
#    Installed Libffi_jll ─────────────────── v3.2.2+1
#    Installed ChainRulesCore ─────────────── v1.24.0
#    Installed DataValueInterfaces ────────── v1.0.0
#    Installed OrderedCollections ─────────── v1.6.3
#    Installed Xorg_libXrender_jll ────────── v0.9.11+0
#    Installed Combinatorics ──────────────── v1.0.2
#    Installed libevdev_jll ───────────────── v1.11.0+0
#    Installed libinput_jll ───────────────── v1.18.0+0
#    Installed Ogg_jll ────────────────────── v1.3.5+1
#    Installed Vulkan_Loader_jll ──────────── v1.3.243+0
#    Installed Xorg_libXi_jll ─────────────── v1.7.10+4
#    Installed XSLT_jll ───────────────────── v1.1.41+0
#    Installed Reexport ───────────────────── v1.2.2
#    Installed Qt6ShaderTools_jll ─────────── v6.7.1+1
#    Installed MacroTools ─────────────────── v0.5.13
#    Installed LogExpFunctions ────────────── v0.3.28
#    Installed OpenSpecFun_jll ────────────── v0.5.5+0
#    Installed HDF5 ───────────────────────── v0.17.2
#    Installed Qt6Declarative_jll ─────────── v6.7.1+2
#    Installed CommonSolve ────────────────── v0.2.4
#    Installed AliasTables ────────────────── v1.1.3
#    Installed DocStringExtensions ────────── v0.9.3
#    Installed CompositionsBase ───────────── v0.1.2
#    Installed Xorg_libXcursor_jll ────────── v1.2.0+4
#    Installed InverseFunctions ───────────── v0.1.15
#    Installed Libuuid_jll ────────────────── v2.40.1+0
#    Installed StableRNGs ─────────────────── v1.0.2
#    Installed Wayland_protocols_jll ──────── v1.31.0+0
#    Installed Xorg_libICE_jll ────────────── v1.1.1+0
#    Installed libaec_jll ─────────────────── v1.1.2+0
#    Installed Xorg_xcb_util_renderutil_jll ─ v0.3.9+1
#    Installed Crayons ────────────────────── v4.1.1
#    Installed XML2_jll ───────────────────── v2.13.1+0
#    Installed Latexify ───────────────────── v0.16.4
#    Installed Graphite2_jll ──────────────── v1.3.14+0
#    Installed libass_jll ─────────────────── v0.15.1+0
#    Installed Pixman_jll ─────────────────── v0.43.4+0
#    Installed OpenSSL_jll ────────────────── v3.0.14+0
#    Installed Rmath ──────────────────────── v0.7.1
#    Installed BitFlags ───────────────────── v0.1.9
#    Installed DualNumbers ────────────────── v0.6.8
#    Installed Gettext_jll ────────────────── v0.21.0+0
#    Installed Wayland_jll ────────────────── v1.21.0+1
#    Installed Xorg_xtrans_jll ────────────── v1.5.0+0
#    Installed FFMPEG_jll ─────────────────── v4.4.4+1
#    Installed Libgcrypt_jll ──────────────── v1.8.11+0
#    Installed Xorg_xkeyboard_config_jll ──── v2.39.0+0
#    Installed DataAPI ────────────────────── v1.16.0
#    Installed Tables ─────────────────────── v1.12.0
#    Installed LLVMOpenMP_jll ─────────────── v15.0.7+0
#    Installed RecipesBase ────────────────── v1.3.4
#    Installed FixedPointNumbers ──────────── v0.8.5
#    Installed Xorg_libXrandr_jll ─────────── v1.5.2+4
#    Installed Libiconv_jll ───────────────── v1.17.0+0
#    Installed URIs ───────────────────────── v1.5.1
#    Installed LaTeXStrings ───────────────── v1.3.1
#    Installed Xorg_libXfixes_jll ─────────── v5.0.3+4
#    Installed LAME_jll ───────────────────── v3.100.2+0
#    Installed Qt6Wayland_jll ─────────────── v6.7.1+1
#    Installed IteratorInterfaceExtensions ── v1.0.0
#    Installed Qt6Base_jll ────────────────── v6.7.1+1
#    Installed Glib_jll ───────────────────── v2.80.2+0
#    Installed Requires ───────────────────── v1.3.0
#    Installed libvorbis_jll ──────────────── v1.3.7+2
#    Installed Libglvnd_jll ───────────────── v1.6.0+0
#    Installed FillArrays ─────────────────── v1.11.0
#    Installed QuadGK ─────────────────────── v2.9.4
#    Installed MPItrampoline_jll ──────────── v5.4.0+0
#    Installed ShiftedArrays ──────────────── v2.0.0
#    Installed Xorg_libX11_jll ────────────── v1.8.6+0
#    Installed Xorg_libXdmcp_jll ──────────── v1.1.4+0
#    Installed UnitfulLatexify ────────────── v1.6.4
#    Installed Unzip ──────────────────────── v0.2.0
#    Installed Distributions ──────────────── v0.25.109
#    Installed StringManipulation ─────────── v0.3.4
#    Installed SortingAlgorithms ──────────── v1.2.1
#     Updating `~/.julia/environments/v1.10/Project.toml`
#   [3e78decc] + Jevo v0.0.2-DEV `https://github.com/jarbus/Jevo.jl.git#phylo-tutorial`
#   [6d56a5a2] + PhylogeneticTrees v1.0.3-DEV `https://github.com/jarbus/PhylogeneticTrees.jl.git#master`
#   [860ef19b] + StableRNGs v1.0.2
#   [2913bbd2] + StatsBase v0.34.3
#   [05f8af49] + XPlot v1.2.0 `https://github.com/jarbus/XPlot.jl.git#master`
#   [56ddb016] + Logging
#     Updating `~/.julia/environments/v1.10/Manifest.toml`
#   [7d9f7c33] + Accessors v0.1.37
#   [66dad0bd] + AliasTables v1.1.3
#   [d1d4a3ce] + BitFlags v0.1.9
#   [e28b5b4c] + Bootstrap v2.4.0
#   [49dc2e85] + Calculus v0.5.1
#   [d360d2e6] + ChainRulesCore v1.24.0
#   [944b1d66] + CodecZlib v0.7.5
#   [35d6a980] + ColorSchemes v3.26.0
#   [3da002f7] + ColorTypes v0.11.5
#   [c3611d14] + ColorVectorSpace v0.10.0
#   [5ae59095] + Colors v0.12.11
#   [861a8166] + Combinatorics v1.0.2
#   [38540f10] + CommonSolve v0.2.4
#   [34da2185] + Compat v4.15.0
#   [a33af91c] + CompositionsBase v0.1.2
#   [f0e56b4a] + ConcurrentUtilities v2.4.2
#   [187b0558] + ConstructionBase v1.5.6
#   [d38c429a] + Contour v0.6.3
#   [a8cc5b0e] + Crayons v4.1.1
#   [9a962f9c] + DataAPI v1.16.0
#   [a93c6f00] + DataFrames v1.6.1
#   [864edb3b] + DataStructures v0.18.20
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [31c24e10] + Distributions v0.25.109
#   [ffbed154] + DocStringExtensions v0.9.3
#   [fa6b7ba4] + DualNumbers v0.6.8
#   [460bff9d] + ExceptionUnwrapping v0.1.10
#   [c87230d0] + FFMPEG v0.4.1
#   [1a297f60] + FillArrays v1.11.0
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [1fa38f19] + Format v1.3.7
#   [28b8d3ca] + GR v0.73.7
#   [42e2da0e] + Grisu v1.0.2
#   [f67ccb44] + HDF5 v0.17.2
#   [cd3eb016] + HTTP v1.10.8
#   [34004b35] + HypergeometricFunctions v0.3.23
#   [09f84164] + HypothesisTests v0.11.0
#   [842dd82b] + InlineStrings v1.4.2
#   [3587e190] + InverseFunctions v0.1.15
#   [41ab1584] + InvertedIndices v1.3.0
#   [92d709cd] + IrrationalConstants v0.2.2
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [1019f520] + JLFzf v0.1.7
#   [3e78decc] + Jevo v0.0.2-DEV `https://github.com/jarbus/Jevo.jl.git#phylo-tutorial`
#   [8ac3fa9e] + LRUCache v1.6.1
#   [b964fa9f] + LaTeXStrings v1.3.1
#   [23fbe1c1] + Latexify v0.16.4
#   [2ab3a3ac] + LogExpFunctions v0.3.28
#   [e6f89c97] + LoggingExtras v1.0.3
#   [3da0fdf6] + MPIPreferences v0.1.11
#   [1914dd2f] + MacroTools v0.5.13
#   [442fdcdd] + Measures v0.3.2
#   [e1d29d7a] + Missings v1.2.0
#   [77ba4419] + NaNMath v1.0.2
#   [4d8831e6] + OpenSSL v1.4.3
#   [bac558e1] + OrderedCollections v1.6.3
#   [90014a1f] + PDMats v0.11.31
#   [6d56a5a2] + PhylogeneticTrees v1.0.3-DEV `https://github.com/jarbus/PhylogeneticTrees.jl.git#master`
#   [b98c9c47] + Pipe v1.3.0
#   [ccf2f8ad] + PlotThemes v3.2.0
#   [995b91a9] + PlotUtils v1.4.1
#   [91a5bcdd] + Plots v1.40.5
#   [2dfb63ee] + PooledArrays v1.4.3
#   [08abe8d2] + PrettyTables v2.3.2
#   [43287f4e] + PtrArrays v1.2.0
#   [1fd47b50] + QuadGK v2.9.4
#   [3cdcf5f2] + RecipesBase v1.3.4
#   [01d81517] + RecipesPipeline v0.6.12
#   [189a3867] + Reexport v1.2.2
#   [05181044] + RelocatableFolders v1.0.1
#   [ae029012] + Requires v1.3.0
#   [79098fc4] + Rmath v0.7.1
#   [f2b01f46] + Roots v2.1.6
#   [6c6a2e73] + Scratch v1.2.1
#   [91c51154] + SentinelArrays v1.4.5
#   [1277b4bf] + ShiftedArrays v2.0.0
#   [992d4aef] + Showoff v1.0.3
#   [777ac1f9] + SimpleBufferStream v1.1.0
#   [a2af1166] + SortingAlgorithms v1.2.1
#   [276daf66] + SpecialFunctions v2.4.0
#   [860ef19b] + StableRNGs v1.0.2
#   [82ae8749] + StatsAPI v1.7.0
#   [2913bbd2] + StatsBase v0.34.3
#   [4c63d2b9] + StatsFuns v1.3.1
#   [3eaba693] + StatsModels v0.7.3
#   [892a3eda] + StringManipulation v0.3.4
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.12.0
#   [62fd8b95] + TensorCore v0.1.1
#   [3bb67fe8] + TranscodingStreams v0.11.1
#   [5c2747f8] + URIs v1.5.1
#   [1cfade01] + UnicodeFun v0.4.1
#   [1986cc42] + Unitful v1.21.0
#   [45397f5d] + UnitfulLatexify v1.6.4
#   [41fe7b60] + Unzip v0.2.0
#   [05f8af49] + XPlot v1.2.0 `https://github.com/jarbus/XPlot.jl.git#master`
#   [6e34b625] + Bzip2_jll v1.0.8+1
#   [83423d85] + Cairo_jll v1.18.0+2
#   [2702e6a9] + EpollShim_jll v0.0.20230411+0
#   [2e619515] + Expat_jll v2.6.2+0
# ⌅ [b22a6f82] + FFMPEG_jll v4.4.4+1
#   [a3f928ae] + Fontconfig_jll v2.13.96+0
#   [d7e528f0] + FreeType2_jll v2.13.2+0
#   [559328eb] + FriBidi_jll v1.0.14+0
#   [0656b61e] + GLFW_jll v3.4.0+0
#   [d2c73de3] + GR_jll v0.73.7+0
#   [78b55507] + Gettext_jll v0.21.0+0
#   [7746bdde] + Glib_jll v2.80.2+0
#   [3b182d85] + Graphite2_jll v1.3.14+0
#   [0234f1f7] + HDF5_jll v1.14.3+3
#   [2e76f6c2] + HarfBuzz_jll v2.8.1+1
#   [e33a78d0] + Hwloc_jll v2.11.1+0
#   [aacddb02] + JpegTurbo_jll v3.0.3+0
#   [c1c5ebd0] + LAME_jll v3.100.2+0
# ⌅ [88015f11] + LERC_jll v3.0.0+1
#   [1d63c593] + LLVMOpenMP_jll v15.0.7+0
#   [dd4b983a] + LZO_jll v2.10.2+0
# ⌅ [e9f186c6] + Libffi_jll v3.2.2+1
#   [d4300ac3] + Libgcrypt_jll v1.8.11+0
#   [7e76a0d4] + Libglvnd_jll v1.6.0+0
#   [7add5ba3] + Libgpg_error_jll v1.49.0+0
#   [94ce4f54] + Libiconv_jll v1.17.0+0
#   [4b2f31a3] + Libmount_jll v2.40.1+0
# ⌅ [89763e89] + Libtiff_jll v4.5.1+1
#   [38a345b3] + Libuuid_jll v2.40.1+0
#   [7cb0a576] + MPICH_jll v4.2.2+0
#   [f1f71cc9] + MPItrampoline_jll v5.4.0+0
#   [9237b28f] + MicrosoftMPI_jll v10.1.4+2
#   [e7412a2a] + Ogg_jll v1.3.5+1
# ⌅ [fe0851c0] + OpenMPI_jll v4.1.6+0
#   [458c3c95] + OpenSSL_jll v3.0.14+0
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [91d4177d] + Opus_jll v1.3.2+0
#   [30392449] + Pixman_jll v0.43.4+0
#   [c0090381] + Qt6Base_jll v6.7.1+1
#   [629bc702] + Qt6Declarative_jll v6.7.1+2
#   [ce943373] + Qt6ShaderTools_jll v6.7.1+1
#   [e99dba38] + Qt6Wayland_jll v6.7.1+1
#   [f50d1b31] + Rmath_jll v0.4.2+0
#   [a44049a8] + Vulkan_Loader_jll v1.3.243+0
#   [a2964d1f] + Wayland_jll v1.21.0+1
#   [2381bf8a] + Wayland_protocols_jll v1.31.0+0
#   [02c8fc9c] + XML2_jll v2.13.1+0
#   [aed1982a] + XSLT_jll v1.1.41+0
#   [ffd25f8a] + XZ_jll v5.4.6+0
#   [f67eecfb] + Xorg_libICE_jll v1.1.1+0
#   [c834827a] + Xorg_libSM_jll v1.2.4+0
#   [4f6342f7] + Xorg_libX11_jll v1.8.6+0
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.11+0
#   [935fb764] + Xorg_libXcursor_jll v1.2.0+4
#   [a3789734] + Xorg_libXdmcp_jll v1.1.4+0
#   [1082639a] + Xorg_libXext_jll v1.3.6+0
#   [d091e8ba] + Xorg_libXfixes_jll v5.0.3+4
#   [a51aa0fd] + Xorg_libXi_jll v1.7.10+4
#   [d1454406] + Xorg_libXinerama_jll v1.1.4+4
#   [ec84b674] + Xorg_libXrandr_jll v1.5.2+4
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.11+0
#   [14d82f49] + Xorg_libpthread_stubs_jll v0.1.1+0
#   [c7cfdc94] + Xorg_libxcb_jll v1.17.0+0
#   [cc61e674] + Xorg_libxkbfile_jll v1.1.2+0
#   [e920d4aa] + Xorg_xcb_util_cursor_jll v0.1.4+0
#   [12413925] + Xorg_xcb_util_image_jll v0.4.0+1
#   [2def613f] + Xorg_xcb_util_jll v0.4.0+1
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.0+1
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.9+1
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.1+1
#   [35661453] + Xorg_xkbcomp_jll v1.4.6+0
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.39.0+0
#   [c5fb5394] + Xorg_xtrans_jll v1.5.0+0
#   [3161d3a3] + Zstd_jll v1.5.6+0
#   [35ca27e7] + eudev_jll v3.2.9+0
# ⌅ [214eeab7] + fzf_jll v0.43.0+0
#   [1a1c6b14] + gperf_jll v3.1.1+0
#   [477f73a3] + libaec_jll v1.1.2+0
#   [a4ae2306] + libaom_jll v3.9.0+0
#   [0ac62f75] + libass_jll v0.15.1+0
#   [2db6ffa8] + libevdev_jll v1.11.0+0
#   [f638f0a6] + libfdk_aac_jll v2.0.2+0
#   [36db933b] + libinput_jll v1.18.0+0
#   [b53b4c65] + libpng_jll v1.6.43+1
#   [f27f6e37] + libvorbis_jll v1.3.7+2
#   [009596ad] + mtdev_jll v1.1.6+0
#   [1270edf5] + x264_jll v2021.5.5+0
#   [dfaa095f] + x265_jll v3.5.0+0
#   [d8fb68d0] + xkbcommon_jll v1.4.1+1
#   [8ba89e20] + Distributed
#   [9fa8497b] + Future
#   [4af54fe1] + LazyArtifacts
#   [37e2e46d] + LinearAlgebra
#   [2f01184e] + SparseArrays v1.10.0
#   [10745b16] + Statistics v1.10.0
#   [4607b0f0] + SuiteSparse
#   [e66e0078] + CompilerSupportLibraries_jll v1.1.1+0
#   [4536629a] + OpenBLAS_jll v0.3.23+4
#   [05823500] + OpenLibm_jll v0.8.1+2
#   [efcefdf7] + PCRE2_jll v10.42.0+1
#   [bea87d4a] + SuiteSparse_jll v7.2.1+1
#   [8e850b90] + libblastrampoline_jll v5.8.0+1
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ Calculus
#   ✓ Combinatorics
#   ✓ LaTeXStrings
#   ✓ IteratorInterfaceExtensions
#   ✓ TensorCore
#   ✓ SentinelArrays
#   ✓ StatsAPI
#   ✓ Contour
#   ✓ ConcurrentUtilities
#   ✓ Pipe
#   ✓ Measures
#   ✓ Format
#   ✓ FillArrays
#   ✓ InverseFunctions
#   ✓ CommonSolve
#   ✓ CompilerSupportLibraries_jll
#   ✓ Grisu
#   ✓ ShiftedArrays
#   ✓ Compat
#   ✓ OrderedCollections
#   ✓ DataValueInterfaces
#   ✓ Requires
#   ✓ StableRNGs
#   ✓ Unzip
#   ✓ Reexport
#   ✓ DocStringExtensions
#   ✓ MacroTools
#   ✓ MPIPreferences
#   ✓ InlineStrings
#   ✓ URIs
#   ✓ SimpleBufferStream
#   ✓ CompositionsBase
#   ✓ IrrationalConstants
#   ✓ ExceptionUnwrapping
#   ✓ PtrArrays
#   ✓ NaNMath
#   ✓ TranscodingStreams
#   ✓ UnicodeFun
#   ✓ DelimitedFiles
#   ✓ InvertedIndices
#   ✓ LRUCache
#   ✓ DataAPI
#   ✓ ConstructionBase
#   ✓ BitFlags
#   ✓ Scratch
#   ✓ Crayons
#   ✓ LoggingExtras
#   ✓ SuiteSparse
#   ✓ Statistics
#   ✓ RecipesBase
#   ✓ OpenSSL_jll
#   ✓ Graphite2_jll
#   ✓ StringManipulation
#   ✓ EpollShim_jll
#   ✓ Libmount_jll
#   ✓ Bzip2_jll
#   ✓ LLVMOpenMP_jll
#   ✓ libaec_jll
#   ✓ Rmath_jll
#   ✓ Xorg_libICE_jll
#   ✓ Xorg_libXau_jll
#   ✓ libpng_jll
#   ✓ libfdk_aac_jll
#   ✓ Hwloc_jll
#   ✓ LAME_jll
#   ✓ LERC_jll
#   ✓ fzf_jll
#   ✓ JpegTurbo_jll
#   ✓ XZ_jll
#   ✓ mtdev_jll
#   ✓ Ogg_jll
#   ✓ gperf_jll
#   ✓ Xorg_libXdmcp_jll
#   ✓ x265_jll
#   ✓ x264_jll
#   ✓ Zstd_jll
#   ✓ libaom_jll
#   ✓ Expat_jll
#   ✓ LZO_jll
#   ✓ Opus_jll
#   ✓ MicrosoftMPI_jll
#   ✓ Xorg_xtrans_jll
#   ✓ libevdev_jll
#   ✓ Libiconv_jll
#   ✓ Libffi_jll
#   ✓ Libgpg_error_jll
#   ✓ Wayland_protocols_jll
#   ✓ Xorg_libpthread_stubs_jll
#   ✓ FriBidi_jll
#   ✓ Libuuid_jll
#   ✓ TableTraits
#   ✓ InverseFunctions → DatesExt
#   ✓ OpenSpecFun_jll
#   ✓ Showoff
#   ✓ Compat → CompatLinearAlgebraExt
#   ✓ MPItrampoline_jll
#   ✓ OpenMPI_jll
#   ✓ InlineStrings → ParsersExt
#   ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ✓ LogExpFunctions
#   ✓ Latexify
#   ✓ AliasTables
#   ✓ TranscodingStreams → TestExt
#   ✓ LRUCache → SerializationExt
#   ✓ PooledArrays
#   ✓ Missings
#   ✓ RelocatableFolders
#   ✓ PDMats
#   ✓ OpenSSL
#   ✓ FreeType2_jll
#   ✓ FixedPointNumbers
#   ✓ Pixman_jll
#   ✓ Rmath
#   ✓ Xorg_libSM_jll
#   ✓ MPICH_jll
#   ✓ JLFzf
#   ✓ libvorbis_jll
#   ✓ eudev_jll
#   ✓ Libtiff_jll
#   ✓ XML2_jll
#   ✓ Libgcrypt_jll
#   ✓ Tables
#   ✓ ChainRulesCore
#   ✓ Unitful
#   ✓ CodecZlib
#   ✓ DataStructures
#   ✓ Fontconfig_jll
#   ✓ FillArrays → FillArraysPDMatsExt
#   ✓ Accessors
#   ✓ libinput_jll
#   ✓ HDF5_jll
#   ✓ Gettext_jll
#   ✓ Wayland_jll
#   ✓ ColorTypes
#   ✓ XSLT_jll
#   ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#   ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#   ✓ Unitful → InverseFunctionsUnitfulExt
#   ✓ SortingAlgorithms
#   ✓ QuadGK
#   ✓ PhylogeneticTrees
#   ✓ FillArrays → FillArraysSparseArraysExt
#   ✓ HTTP
#   ✓ Accessors → AccessorsUnitfulExt
#   ✓ Glib_jll
#   ✓ Colors
#   ✓ HDF5
#   ✓ Xorg_libxcb_jll
#   ✓ LogExpFunctions → LogExpFunctionsInverseFunctionsExt
#   ✓ ColorVectorSpace
#   ✓ Unitful → ConstructionBaseUnitfulExt
#   ✓ FillArrays → FillArraysStatisticsExt
#   ✓ Xorg_xcb_util_jll
#   ✓ Xorg_libX11_jll
#   ✓ Roots
#   ✓ SpecialFunctions
#   ✓ Xorg_xcb_util_image_jll
#   ✓ Xorg_xcb_util_keysyms_jll
#   ✓ StatsBase
#   ✓ Xorg_xcb_util_renderutil_jll
#   ✓ Xorg_xcb_util_wm_jll
#   ✓ Xorg_libXrender_jll
#   ✓ Xorg_libXext_jll
#   ✓ Xorg_libXfixes_jll
#   ✓ Xorg_libxkbfile_jll
#   ✓ ColorVectorSpace → SpecialFunctionsExt
#   ✓ Xorg_xcb_util_cursor_jll
#   ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#   ✓ Libglvnd_jll
#   ✓ Xorg_libXinerama_jll
#   ✓ Xorg_libXrandr_jll
#   ✓ PrettyTables
#   ✓ Cairo_jll
#   ✓ Xorg_libXcursor_jll
#   ✓ Xorg_libXi_jll
#   ✓ Xorg_xkbcomp_jll
#   ✓ DualNumbers
#   ✓ HarfBuzz_jll
#   ✓ Xorg_xkeyboard_config_jll
#   ✓ HypergeometricFunctions
#   ✓ ColorSchemes
#   ✓ libass_jll
#   ✓ xkbcommon_jll
#   ✓ StatsFuns
#   ✓ FFMPEG_jll
#   ✓ Vulkan_Loader_jll
#   ✓ GLFW_jll
#   ✓ StatsFuns → StatsFunsInverseFunctionsExt
#   ✓ FFMPEG
#   ✓ Qt6Base_jll
#   ✓ StatsFuns → StatsFunsChainRulesCoreExt
#   ✓ Qt6ShaderTools_jll
#   ✓ GR_jll
#   ✓ StatsModels
#   ✓ PlotUtils
#   ✓ Distributions
#   ✓ Qt6Declarative_jll
#   ✓ PlotThemes
#   ✓ Distributions → DistributionsTestExt
#   ✓ Qt6Wayland_jll
#   ✓ Distributions → DistributionsChainRulesCoreExt
#   ✓ RecipesPipeline
#   ✓ HypothesisTests
#   ✓ GR
#   ✓ DataFrames
#   ✓ Latexify → DataFramesExt
#   ✓ Bootstrap
#   ✓ UnitfulLatexify
#   ✓ Plots
#   ✓ Plots → UnitfulExt
#   ✓ Plots → IJuliaExt
#   ✓ XPlot
#   ✓ Jevo
#   213 dependencies successfully precompiled in 489 seconds. 21 already precompiled.

# %% [markdown]
# # The world's simplest Co-Evolutionary Algorithm
#
# We will be implementing a trivial, one-dimensional version of the Number's Game from scratch, and then demonstrating a completed example using the Jevo.jl framework. You can implement phylogeny tracking using [PhylogeneticTrees.jl](https://github.com/jarbus/PhylogeneticTrees.jl/blob/master/src/tree.jl). There is no documentation yet for this package, so we provide the API where relevant, which is straightforward to use.

# %%
using StatsBase

mutable struct Organism
  id::Int
  genome::Float64  # Genome is a single float, which co-evolves with other floats to rise in value
  fitness::Float64
end
Organism(id::Int, genome::Float64) = Organism(id, genome, 0)


function mutate_genome(genome::Float64; mr::Float64)
  genome + (rand() * mr)
end

function evaluate_fitness!(pop_a::Vector{Organism}, pop_b::Vector{Organism})
  for org_a in pop_a, org_b in pop_b
    org_a.fitness += org_a.genome > org_b.genome
    org_b.fitness += org_a.genome < org_b.genome
  end
end

function fitness_proportional_selection(n_parents::Int, pop::Vector{Organism})
  weights = [org.fitness for org in pop]
  [sample(pop, Weights(weights)) for _ in 1:n_parents]
end
# Out:
# fitness_proportional_selection (generic function with 1 method)

# %%
using PhylogeneticTrees
# Create two co-evolving populations
# Yes, this code is *horribly* inefficient
# We write it this way for clarity.
n_pop = 100
n_gens = 100
mr = 0.1

org_id = 1
pop_a, pop_b = Organism[], Organism[]
for _ in 1:n_pop
  push!(pop_a, Organism(org_id, rand()))
  push!(pop_b, Organism(org_id + 1, rand()))
  org_id += 2
end

"""
TUTORIAL TASK: Initialization

Create a new phylogenetic tree for each population. The relevant constructor is:

  function PhylogeneticTrees(genesis_pop_ids::Vector{Int})
"""

tree_a = PhylogeneticTree([o.id for o in pop_a])
tree_b = PhylogeneticTree([o.id for o in pop_b])

for gen in 1:n_gens
  evaluate_fitness!(pop_a, pop_b)
  parents_a = fitness_proportional_selection(n_pop, pop_a)
  parents_b = fitness_proportional_selection(n_pop, pop_b)
  next_pop_a, next_pop_b = Organism[], Organism[]

  # Create next generation
  for parent_a in parents_a
    new_child_a = Organism(org_id, mutate_genome(parent_a.genome, mr=mr))
    """
    TUTORIAL TASK: Update phylogeny for population a. Relevant function:

      function add_child!(tree::PhylogeneticTree, parent_id::Int, child_id::Int)
    """
    add_child!(tree_a, parent_a.id, new_child_a.id)
    push!(next_pop_a, new_child_a)
    org_id += 1
  end

  for parent_b in parents_b
    new_child_b = Organism(org_id, mutate_genome(parent_b.genome, mr=mr))
    """
    TUTORIAL TASK: Update phylogeny for population b. Relevant function:

      function add_child!(tree::PhylogeneticTree, parent_id::Int, child_id::Int)
    """
    add_child!(tree_b, parent_b.id, new_child_b.id)
    push!(next_pop_b, new_child_b)
    org_id += 1
  end
  pop_a = next_pop_a
  pop_b = next_pop_b
  @assert length(pop_a) == n_pop == length(pop_b)


  """"
  TUTORIAL TASK: Prune phylogeny of dead branches, saving memory. Relevant function:

    function purge_unreachable_nodes!(tree::PhylogeneticTree, ids::Set{Int})

  # Arguments:
    `ids` refers to a set of existing individual ids in a population to keep the lineages for. Any nodes
    in the tree which are not ancestors of any individual in this set will be deleted.
  """
  purge_unreachable_nodes!(tree_a, Set(o.id for o in pop_a))
  purge_unreachable_nodes!(tree_b, Set(o.id for o in pop_b))


  """
  OTHER (VERY OPTIONAL) TUTORIAL TASK: Compute pairwise distances between nodes in tree. Relevant function

    function compute_pairwise_distances!(tree::PhylogeneticTree, ids::Set{Int};)

    To view information about the returned types, see the function docstring: (MRCA = Most Recent Common Ancestor)

    https://github.com/jarbus/PhylogeneticTrees.jl/blob/4179f72050e4c4a3bb99da71a1d727f6ddd6074d/src/tree.jl#L92
  """

  if gen % 10 == 0
    pop_a_mean = round(mean(o.genome for o in pop_a), digits=2)
    pop_b_mean = round(mean(o.genome for o in pop_b), digits=2)
    println("gen $gen: average genome in pop a = $pop_a_mean")
    println("gen $gen: average genome in pop b = $pop_b_mean")
  end
end
# Out:
# gen 10: average genome in pop a = 1.67
# gen 10: average genome in pop b = 1.68
# gen 20: average genome in pop a = 2.46
# gen 20: average genome in pop b = 2.47
# gen 30: average genome in pop a = 3.25
# gen 30: average genome in pop b = 3.27
# gen 40: average genome in pop a = 4.03
# gen 40: average genome in pop b = 4.05
# gen 50: average genome in pop a = 4.8
# gen 50: average genome in pop b = 4.8
# gen 60: average genome in pop a = 5.59
# gen 60: average genome in pop b = 5.6
# gen 70: average genome in pop a = 6.36
# gen 70: average genome in pop b = 6.36
# gen 80: average genome in pop a = 7.17
# gen 80: average genome in pop b = 7.17
# gen 90: average genome in pop a = 7.94
# gen 90: average genome in pop b = 7.94
# gen 100: average genome in pop a = 8.72
# gen 100: average genome in pop b = 8.73

# %%
function write_phylogeny(filename::String, tree::PhylogeneticTree)
  open(filename, "w") do io
    println(io, "id,ancestor_list")
    for id in keys(tree.tree) |> collect |> sort
      node = tree.tree[id]
      # for visualization purposes, we put all genesis organisms under a dummy parent
      if isnothing(node.parent)
        println(io, "$id,[none]")
      else
        println(io, "$id,[$(node.parent.id)]")
      end
    end
  end
end

"""
TUTORIAL TASK: Write phylogeny of each population to disk

  We implement the above function to write a phylogeny to disk. Use it to log the phylogenies for your populations!

  Here, your phylogenies files should be should be called `pop_a_custom.csv` and `pop_b_custom.csv`
"""

write_phylogeny("pop_a_custom.csv", tree_a)
write_phylogeny("pop_b_custom.csv", tree_b)

# %% [markdown]
# # Using Jevo
#
# Jevo implements phylogeny tracking with PhylogeneticTrees via the [Operator](https://jarbus.net/Jevo.jl/dev/api/#Jevo.Operator) interface. In the cell below, we provide a completed example of using phylogeny tracking in a simple Jevo pipeline.

# %%
using Jevo
using Logging
using StableRNGs

STATS_FILE = "statistics.h5"
isfile(STATS_FILE) && rm(STATS_FILE)

global_logger(JevoLogger())
rng = StableRNG(1)

k = 10
n_dims = 2
n_inds = 100
n_species = 2
n_gens = 100

counters = default_counters()
ng_gc = ng_genotype_creator = Creator(VectorGenotype, (n=n_dims,rng=rng))
ng_developer = Creator(VectorPhenotype)

# Create Composite population with two subpopulations, p1 and p2
comp_pop_creator = Creator(CompositePopulation, ("species", [("p$i", n_inds, ng_gc, ng_developer) for i in 1:n_species], counters))
env_creator = Creator(CompareOnOne)

state = State("numbers_game", rng,
    # State accepts a list of creators
    [comp_pop_creator, env_creator],
    # and a sequence of operators to apply to the state
    [InitializeAllPopulations(),
    InitializePhylogeny(),
    AllVsAllMatchMaker(),
    Performer(),
    ScalarFitnessEvaluator(),
    TruncationSelector(k),
    CloneUniformReproducer(n_inds),
    Mutator(),
    UpdatePhylogeny(),
    TrackPhylogeny(),  # Adds phylogeny updates to disk
    PurgePhylogeny(),  # removes individuals with no surviving descendants
    ClearInteractionsAndRecords(),
    Reporter(GenotypeSum, console=true)], counters=counters)

println("running")
run!(state, n_gens)
# Out:
# Compiling Jevo...
# running
# gen=1 GenotypeSum: |-1.539, 1.704 ± 1.283, 5.903|, 200 samples
# gen=2 GenotypeSum: |0.352, 4.028 ± 1.47, 8.863|, 200 samples
# gen=3 GenotypeSum: |1.629, 6.886 ± 1.803, 12.08|, 200 samples
# gen=4 GenotypeSum: |3.163, 9.073 ± 1.894, 13.461|, 200 samples
# gen=5 GenotypeSum: |3.354, 10.767 ± 2.082, 15.175|, 200 samples
# gen=6 GenotypeSum: |5.265, 11.724 ± 2.405, 17.915|, 200 samples
# gen=7 GenotypeSum: |7.871, 13.73 ± 2.437, 19.762|, 200 samples
# gen=8 GenotypeSum: |10.216, 15.517 ± 2.006, 20.396|, 200 samples
# gen=9 GenotypeSum: |11.682, 16.18 ± 1.82, 20.235|, 200 samples
# gen=10 GenotypeSum: |12.992, 18.33 ± 1.62, 23.563|, 200 samples
# gen=11 GenotypeSum: |14.584, 19.816 ± 2.272, 25.748|, 200 samples
# gen=12 GenotypeSum: |17.016, 22.451 ± 2.039, 28.045|, 200 samples
# gen=13 GenotypeSum: |19.206, 24.5 ± 2.272, 31.216|, 200 samples
# gen=14 GenotypeSum: |18.902, 26.349 ± 2.47, 32.426|, 200 samples
# gen=15 GenotypeSum: |21.741, 28.899 ± 2.869, 35.476|, 200 samples
# gen=16 GenotypeSum: |21.269, 28.922 ± 2.819, 36.08|, 200 samples
# gen=17 GenotypeSum: |25.718, 30.566 ± 2.447, 37.749|, 200 samples
# gen=18 GenotypeSum: |27.145, 32.291 ± 2.231, 40.349|, 200 samples
# gen=19 GenotypeSum: |25.672, 33.144 ± 2.541, 39.429|, 200 samples
# gen=20 GenotypeSum: |29.321, 34.618 ± 2.995, 42.193|, 200 samples
# gen=21 GenotypeSum: |29.306, 34.474 ± 2.857, 44.16|, 200 samples
# gen=22 GenotypeSum: |29.802, 36.091 ± 2.029, 40.961|, 200 samples
# gen=23 GenotypeSum: |31.004, 37.976 ± 2.0, 43.364|, 200 samples
# gen=24 GenotypeSum: |34.111, 39.894 ± 1.865, 45.211|, 200 samples
# gen=25 GenotypeSum: |36.423, 42.164 ± 1.988, 46.997|, 200 samples
# gen=26 GenotypeSum: |39.206, 43.763 ± 2.04, 49.551|, 200 samples
# gen=27 GenotypeSum: |38.87, 46.163 ± 2.303, 51.838|, 200 samples
# gen=28 GenotypeSum: |39.238, 47.875 ± 2.552, 53.099|, 200 samples
# gen=29 GenotypeSum: |43.117, 49.984 ± 2.297, 54.399|, 200 samples
# gen=30 GenotypeSum: |48.158, 52.256 ± 1.709, 56.592|, 200 samples
# gen=31 GenotypeSum: |48.679, 54.233 ± 1.773, 58.834|, 200 samples
# gen=32 GenotypeSum: |51.402, 56.248 ± 2.205, 61.517|, 200 samples
# gen=33 GenotypeSum: |52.88, 59.144 ± 1.929, 65.059|, 200 samples
# gen=34 GenotypeSum: |54.934, 61.334 ± 2.202, 67.394|, 200 samples
# gen=35 GenotypeSum: |58.171, 63.206 ± 2.005, 67.706|, 200 samples
# gen=36 GenotypeSum: |57.181, 64.992 ± 2.257, 69.394|, 200 samples
# gen=37 GenotypeSum: |61.762, 67.153 ± 1.857, 72.174|, 200 samples
# gen=38 GenotypeSum: |62.18, 68.776 ± 2.533, 74.863|, 200 samples
# gen=39 GenotypeSum: |62.493, 70.632 ± 2.92, 78.21|, 200 samples
# gen=40 GenotypeSum: |65.877, 72.368 ± 2.981, 79.665|, 200 samples
# gen=41 GenotypeSum: |67.192, 74.375 ± 3.022, 83.753|, 200 samples
# gen=42 GenotypeSum: |70.498, 76.579 ± 2.919, 85.197|, 200 samples
# gen=43 GenotypeSum: |72.898, 79.67 ± 3.021, 87.641|, 200 samples
# gen=44 GenotypeSum: |74.874, 81.158 ± 3.249, 89.133|, 200 samples
# gen=45 GenotypeSum: |75.236, 81.857 ± 3.203, 89.753|, 200 samples
# gen=46 GenotypeSum: |77.979, 83.671 ± 3.116, 91.584|, 200 samples
# gen=47 GenotypeSum: |78.943, 86.049 ± 3.127, 92.204|, 200 samples
# gen=48 GenotypeSum: |75.652, 86.509 ± 4.196, 93.981|, 200 samples
# gen=49 GenotypeSum: |79.453, 89.434 ± 4.153, 96.903|, 200 samples
# gen=50 GenotypeSum: |84.032, 91.073 ± 3.461, 98.678|, 200 samples
# gen=51 GenotypeSum: |83.437, 93.158 ± 4.185, 101.369|, 200 samples
# gen=52 GenotypeSum: |86.103, 95.101 ± 4.374, 103.379|, 200 samples
# gen=53 GenotypeSum: |87.875, 96.365 ± 3.845, 103.917|, 200 samples
# gen=54 GenotypeSum: |90.863, 98.542 ± 3.961, 106.363|, 200 samples
# gen=55 GenotypeSum: |91.602, 100.269 ± 3.834, 107.842|, 200 samples
# gen=56 GenotypeSum: |94.619, 102.208 ± 3.38, 109.559|, 200 samples
# gen=57 GenotypeSum: |96.027, 103.82 ± 3.453, 110.688|, 200 samples
# gen=58 GenotypeSum: |97.391, 104.295 ± 3.262, 113.086|, 200 samples
# gen=59 GenotypeSum: |96.017, 104.792 ± 3.73, 112.257|, 200 samples
# gen=60 GenotypeSum: |98.973, 106.808 ± 3.922, 114.282|, 200 samples
# gen=61 GenotypeSum: |101.881, 108.881 ± 3.364, 116.56|, 200 samples
# gen=62 GenotypeSum: |103.243, 111.133 ± 3.456, 119.983|, 200 samples
# gen=63 GenotypeSum: |106.752, 113.53 ± 3.42, 122.21|, 200 samples
# gen=64 GenotypeSum: |106.641, 115.385 ± 4.676, 125.467|, 200 samples
# gen=65 GenotypeSum: |105.841, 117.303 ± 5.88, 127.401|, 200 samples
# gen=66 GenotypeSum: |110.592, 120.968 ± 5.062, 130.49|, 200 samples
# gen=67 GenotypeSum: |112.417, 123.158 ± 5.36, 132.443|, 200 samples
# gen=68 GenotypeSum: |115.3, 125.067 ± 4.326, 133.933|, 200 samples
# gen=69 GenotypeSum: |119.252, 127.366 ± 3.19, 134.256|, 200 samples
# gen=70 GenotypeSum: |122.439, 129.291 ± 3.34, 136.557|, 200 samples
# gen=71 GenotypeSum: |123.171, 130.876 ± 3.49, 138.813|, 200 samples
# gen=72 GenotypeSum: |125.015, 132.844 ± 3.664, 139.94|, 200 samples
# gen=73 GenotypeSum: |125.624, 134.07 ± 4.407, 142.118|, 200 samples
# gen=74 GenotypeSum: |126.664, 135.84 ± 4.517, 144.052|, 200 samples
# gen=75 GenotypeSum: |129.529, 138.497 ± 3.704, 145.716|, 200 samples
# gen=76 GenotypeSum: |130.98, 140.308 ± 3.721, 148.2|, 200 samples
# gen=77 GenotypeSum: |134.657, 143.462 ± 3.518, 151.243|, 200 samples
# gen=78 GenotypeSum: |135.683, 145.186 ± 3.243, 154.979|, 200 samples
# gen=79 GenotypeSum: |139.627, 146.846 ± 3.114, 155.894|, 200 samples
# gen=80 GenotypeSum: |143.294, 149.2 ± 2.87, 159.216|, 200 samples
# gen=81 GenotypeSum: |145.008, 151.455 ± 3.639, 162.839|, 200 samples
# gen=82 GenotypeSum: |144.135, 155.087 ± 5.112, 165.855|, 200 samples
# gen=83 GenotypeSum: |147.034, 156.787 ± 5.325, 167.947|, 200 samples
# gen=84 GenotypeSum: |146.425, 158.772 ± 4.989, 168.676|, 200 samples
# gen=85 GenotypeSum: |152.653, 160.147 ± 3.821, 168.13|, 200 samples
# gen=86 GenotypeSum: |153.783, 161.62 ± 3.785, 169.444|, 200 samples
# gen=87 GenotypeSum: |154.118, 162.769 ± 4.237, 171.772|, 200 samples
# gen=88 GenotypeSum: |156.059, 165.232 ± 3.596, 173.907|, 200 samples
# gen=89 GenotypeSum: |158.925, 166.975 ± 3.897, 177.746|, 200 samples
# gen=90 GenotypeSum: |160.513, 168.834 ± 4.314, 175.178|, 200 samples
# gen=91 GenotypeSum: |163.788, 171.06 ± 3.249, 178.394|, 200 samples
# gen=92 GenotypeSum: |165.573, 172.598 ± 3.223, 179.485|, 200 samples
# gen=93 GenotypeSum: |165.903, 174.71 ± 3.172, 183.098|, 200 samples
# gen=94 GenotypeSum: |168.645, 176.882 ± 3.361, 186.145|, 200 samples
# gen=95 GenotypeSum: |171.166, 179.55 ± 4.014, 188.385|, 200 samples
# gen=96 GenotypeSum: |168.935, 180.715 ± 5.389, 189.779|, 200 samples
# gen=97 GenotypeSum: |172.043, 181.797 ± 4.413, 189.903|, 200 samples
# gen=98 GenotypeSum: |176.054, 182.772 ± 2.84, 190.33|, 200 samples
# gen=99 GenotypeSum: |178.32, 183.867 ± 2.517, 189.787|, 200 samples
# gen=100 GenotypeSum: |179.504, 185.38 ± 3.204, 192.76|, 200 samples

# %% [markdown]
# # Viewing the Phylogeny
#
# Jevo outputs phylogenies compliant with the [ALIFE Data Standards](https://github.com/alife-data-standards/alife-data-standards) phylogeny format. Each population outputs a separate phylogeny file. For each of our co-evolutionary setups above, we output two phylogenies. For the custom setup, we output files `pop_a_custom.csv` and `pop_b_custom.csv`. For the Jevo setup, we output files
# `p1-phylo.csv` and `p2-phylo`.csv

# %% [markdown]
# Here, we need to convert from the [ALIFE Data Standards format](https://alife-data-standards.github.io/alife-data-standards/) to the newick file format, which is compatible with [IcyTree](https://icytree.org/)

# %%
;pip install alifedata-phyloinformatics-convert joinem
# Out:
# Collecting alifedata-phyloinformatics-convert
#   Downloading alifedata_phyloinformatics_convert-0.16.3-py2.py3-none-any.whl (34 kB)
# Collecting joinem
#   Downloading joinem-0.2.1-py2.py3-none-any.whl (5.8 kB)
# Collecting anytree>=2.8.0 (from alifedata-phyloinformatics-convert)
#   Downloading anytree-2.12.1-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.2 MB/s eta 0:00:00
# Collecting biopython>=1.79 (from alifedata-phyloinformatics-convert)
#   Downloading biopython-1.84-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from alifedata-phyloinformatics-convert) (8.1.7)
# Collecting dendropy>=4.5.2 (from alifedata-phyloinformatics-convert)
#   Downloading DendroPy-5.0.1-py3-none-any.whl (459 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.5/459.5 kB 38.2 MB/s eta 0:00:00
# Collecting Deprecated>=1.2.13 (from alifedata-phyloinformatics-convert)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting ete3>=3.0.0 (from alifedata-phyloinformatics-convert)
#   Downloading ete3-3.1.3.tar.gz (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 62.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting iterpop>=0.4.0 (from alifedata-phyloinformatics-convert)
#   Downloading iterpop-0.4.1-py2.py3-none-any.whl (4.2 kB)
# Collecting lyncs-utils>=0.3.2 (from alifedata-phyloinformatics-convert)
#   Downloading lyncs_utils-0.5.1.tar.gz (27 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting nanto>=0.1.1 (from alifedata-phyloinformatics-convert)
#   Downloading nanto-0.1.1-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.10/dist-packages (from alifedata-phyloinformatics-convert) (3.3)
# Requirement already satisfied: numpy>=1.21.5 in /usr/local/lib/python3.10/dist-packages (from alifedata-phyloinformatics-convert) (1.25.2)
# Collecting opytional>=0.1.0 (from alifedata-phyloinformatics-convert)
#   Downloading opytional-0.1.0-py2.py3-none-any.whl (5.8 kB)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from alifedata-phyloinformatics-convert) (2.0.3)
# Collecting phylotrackpy>=0.1.16 (from alifedata-phyloinformatics-convert)
#   Downloading phylotrackpy-0.2.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.5/249.5 kB 20.5 MB/s eta 0:00:00
# Requirement already satisfied: sortedcontainers>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from alifedata-phyloinformatics-convert) (2.4.0)
# Requirement already satisfied: typing-extensions>=4.7.1 in /usr/local/lib/python3.10/dist-packages (from alifedata-phyloinformatics-convert) (4.12.2)
# Collecting validators>=0.20.0 (from alifedata-phyloinformatics-convert)
#   Downloading validators-0.33.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: yarl>=1.9.3 in /usr/local/lib/python3.10/dist-packages (from alifedata-phyloinformatics-convert) (1.9.4)
# Requirement already satisfied: polars in /usr/local/lib/python3.10/dist-packages (from joinem) (0.20.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from joinem) (4.66.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from anytree>=2.8.0->alifedata-phyloinformatics-convert) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from dendropy>=4.5.2->alifedata-phyloinformatics-convert) (67.7.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated>=1.2.13->alifedata-phyloinformatics-convert) (1.14.1)
# Collecting dataclasses (from lyncs-utils>=0.3.2->alifedata-phyloinformatics-convert)
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting lyncs-setuptools (from lyncs-utils>=0.3.2->alifedata-phyloinformatics-convert)
#   Using cached lyncs_setuptools-0.3.2-py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->alifedata-phyloinformatics-convert) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->alifedata-phyloinformatics-convert) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->alifedata-phyloinformatics-convert) (2024.1)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl>=1.9.3->alifedata-phyloinformatics-convert) (3.7)
# Requirement already satisfied: multidict>=4.0 in /usr/local/lib/python3.10/dist-packages (from yarl>=1.9.3->alifedata-phyloinformatics-convert) (6.0.5)
# Collecting gitpython (from lyncs-setuptools->lyncs-utils>=0.3.2->alifedata-phyloinformatics-convert)
#   Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (from lyncs-setuptools->lyncs-utils>=0.3.2->alifedata-phyloinformatics-convert) (23.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from lyncs-setuptools->lyncs-utils>=0.3.2->alifedata-phyloinformatics-convert) (24.1)
# Collecting gitdb<5,>=4.0.1 (from gitpython->lyncs-setuptools->lyncs-utils>=0.3.2->alifedata-phyloinformatics-convert)
#   Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython->lyncs-setuptools->lyncs-utils>=0.3.2->alifedata-phyloinformatics-convert)
#   Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: ete3, lyncs-utils
#   Building wheel for ete3 (setup.py): started
#   Building wheel for ete3 (setup.py): finished with status 'done'
#   Created wheel for ete3: filename=ete3-3.1.3-py3-none-any.whl size=2273786 sha256=6968bedef3c3108c3002236306124421ac2b184509d4767a9b0f1f0421430899
#   Stored in directory: /root/.cache/pip/wheels/a0/72/00/1982bd848e52b03079dbf800900120bc1c20e92e9a1216e525
#   Building wheel for lyncs-utils (pyproject.toml): started
#   Building wheel for lyncs-utils (pyproject.toml): finished with status 'done'
#   Created wheel for lyncs-utils: filename=lyncs_utils-0.5.1-py3-none-any.whl size=25336 sha256=b0411cd9310408c26917895a90e78b3878be584ef395a2f2bb42587f1605f19c
#   Stored in directory: /root/.cache/pip/wheels/ea/92/2d/ec3d31eb5cc14671c702f6d133e6a189003217de896396688a
# Successfully built ete3 lyncs-utils
# Installing collected packages: ete3, dataclasses, validators, smmap, phylotrackpy, opytional, nanto, joinem, iterpop, Deprecated, dendropy, biopython, anytree, gitdb, gitpython, lyncs-setuptools, lyncs-utils, alifedata-phyloinformatics-convert
# Successfully installed Deprecated-1.2.14 alifedata-phyloinformatics-convert-0.16.3 anytree-2.12.1 biopython-1.84 dataclasses-0.6 dendropy-5.0.1 ete3-3.1.3 gitdb-4.0.11 gitpython-3.1.43 iterpop-0.4.1 joinem-0.2.1 lyncs-setuptools-0.3.2 lyncs-utils-0.5.1 nanto-0.1.1 opytional-0.1.0 phylotrackpy-0.2.2 smmap-5.0.1 validators-0.33.0

# %%
# Don't worry about the details of these cells We need to execute complex bash commands like this because
# this notebook uses a julia runtime and doesn't like special symbols.
open("convert.sh", "w") do io
println(io, """
#!/bin/bash

echo pop_a_custom.csv | python3 -m joinem pop_a_custom_aliased.csv --with-column "pl.col('id').alias('taxon_label')"
alifedata-phyloinformatics-convert fromalifedata --input-file pop_a_custom_aliased.csv --output-schema newick --output-file pop_a_custom_aliased.newick

echo pop_b_custom.csv | python3 -m joinem pop_b_custom_aliased.csv --with-column "pl.col('id').alias('taxon_label')"
alifedata-phyloinformatics-convert fromalifedata --input-file pop_b_custom_aliased.csv --output-schema newick --output-file pop_b_custom_aliased.newick

echo p1-phylo.csv | python3 -m joinem p1-phylo-aliased.csv --with-column "pl.col('id').alias('taxon_label')"
alifedata-phyloinformatics-convert fromalifedata --input-file p1-phylo-aliased.csv --output-schema newick --output-file p1-phylo-aliased.newick

echo p2-phylo.csv | python3 -m joinem p2-phylo-aliased.csv --with-column "pl.col('id').alias('taxon_label')"
alifedata-phyloinformatics-convert fromalifedata --input-file p2-phylo-aliased.csv --output-schema newick --output-file p2-phylo-aliased.newick

rm pop_a_custom_aliased.csv pop_b_custom_aliased.csv p1-phylo-aliased.csv p2-phylo-aliased.csv
""")
end

# %%
;bash convert.sh

# %% [markdown]
# Convert your phylogenies to .newick files and upload them to [icytree](https://icytree.org) to view them!
